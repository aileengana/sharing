# %% [markdown]
# # Analysis

# %% [markdown]
# ### Goal: Identify customer segments for Oodle to target through marketing

# %% [markdown]
# ### Import libaries

# %%
#Pandas for managing datasets
import pandas as pd

#Matploblib for additional customisation
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/jovyan/binder'
